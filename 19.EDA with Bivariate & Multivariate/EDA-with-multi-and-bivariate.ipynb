# %% [markdown]
# # Importing libraries

# %%
import pandas as pd 
import seaborn as sns

# %% [markdown]
# # Loading dataset

# %%
tips= sns.load_dataset("tips ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tips= sns.load_dataset("tips ")
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'tips ' is not one of the example datasets.
