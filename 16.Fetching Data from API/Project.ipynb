# %% [markdown]
# **import library**

# %%
import pandas as pd

# %%
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=296948dca878a7f7295a340b20e6a962")

# %% [markdown]
# **Convert into json**

# %%
response.json()["results"]
# Out:
# [{'adult': False,
#   'backdrop_path': '/ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg',
#   'genre_ids': [16, 28, 12, 14],
#   'id': 980431,
#   'title': 'Avatar Aang: The Last Airbender',
#   'original_language': 'en',
#   'original_title': 'Avatar Aang: The Last Airbender',
#   'overview': "Avatar Aang, the world's last Airbender, learns of an ancient power that could save his culture from extinction. With the help of his friends, he embarks on a global quest to find it before it falls into the wrong hands and threatens to upend the peace they sacrificed everything to achieve.",
#   'popularity': 174.4534,
#   'poster_path': '/3sgnSfNT27Bx5O5ukr7B26mhEQq.jpg',
#   'release_date': '2026-07-24',
#   'softcore': False,
#   'video': False,
#   'vote_average': 9.266,
#   'vote_count': 779},
#  {'adult': False,
#   'backdrop_path': '/iCML6fBe3X0y06P33bM7dyYXPKZ.jpg',
#   'genre_ids': [35, 10749],
#   'id': 1632181,
#   'title': 'Accidental Partners',
#   'original_language': 'es',
#   'original_title': 'Socias por accidente',
#   'overview': 'Two women discover they were both scammed by the same man (who also got them pregnant). They form an alliance to take revenge.',
#   'popularity': 25.2919,
#   'poster_path': '/j0CIVzeR7hRAPBPGR54qDZoOQpp.jpg',
#   'release_date': '2026-03-12',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.899,
#   'vote_count': 347},
#  {'adult': False,
#   'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#   'genre_ids': [12, 16, 10751, 14],
#   'id': 1007757,
#   'title': 'Swapped',
#   'original_language': 'en',
#   'original_title': 'Swapped',
#   'overview': 'A small woodland creature and a majestic bird, two natural sworn enemies of the Valley, magically trade places and set off on an adventure of a lifetime to switch back. Their journey soon uncovers a greater threat—one that could endanger not only their species, but the entire valley they call home.',
#   'popularity': 65.6704,
#   'poster_path': '/tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg',
#   'release_date': '2026-05-01',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.886,
#   'vote_count': 2083},
#  {'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'title': 'The Shawshank Redemption',
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 64.6793,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.727,
#   'vote_count': 30979},
#  {'adult': False,
#   'backdrop_path': '/ufSwlnECLoUbBjPrFqEQcWBzHwc.jpg',
#   'genre_ids': [10402, 18],
#   'id': 936075,
#   'title': 'Michael',
#   'original_language': 'en',
#   'original_title': 'Michael',
#   'overview': 'The story of Michael Jackson, one of the most influential artists the world has ever known, and his life beyond the music. His journey from the discovery of his extraordinary talent as the lead of the Jackson Five, to the visionary artist whose creative ambition fueled a relentless pursuit to become the biggest entertainer in the world, highlighting both his life off-stage and some of the most iconic performances from his early solo career.',
#   'popularity': 89.4142,
#   'poster_path': '/zm0KAbOjlt9eR5y7vDiL2dEOwMl.jpg',
#   'release_date': '2026-04-22',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.691,
#   'vote_count': 3952},
#  {'adult': False,
#   'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'title': 'The Godfather',
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 48.1392,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.686,
#   'vote_count': 23307},
#  {'adult': False,
#   'backdrop_path': '/1RgPyOhN4DRs225BGTlHJqCudII.jpg',
#   'genre_ids': [16, 28, 14],
#   'id': 1311031,
#   'title': 'Demon Slayer: Kimetsu no Yaiba Infinity Castle',
#   'original_language': 'ja',
#   'original_title': '劇場版「鬼滅の刃」無限城編 第一章 猗窩座再来',
#   'overview': 'The Demon Slayer Corps are drawn into the Infinity Castle, where Tanjiro, Nezuko, and the Hashira face terrifying Upper Rank demons in a desperate fight as the final battle against Muzan Kibutsuji begins.',
#   'popularity': 120.8045,
#   'poster_path': '/fWVSwgjpT2D78VUh6X8UBd2rorW.jpg',
#   'release_date': '2025-07-18',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.679,
#   'vote_count': 1753},
#  {'adult': False,
#   'backdrop_path': '/8Tfys3mDZVp4tNoH2ktm06a0Tau.jpg',
#   'genre_ids': [878, 12],
#   'id': 687163,
#   'title': 'Project Hail Mary',
#   'original_language': 'en',
#   'original_title': 'Project Hail Mary',
#   'overview': 'Science teacher Ryland Grace wakes up on a spaceship light years from home with no recollection of who he is or how he got there. As his memory returns, he begins to uncover his mission: solve the riddle of the mysterious substance causing the sun to die out. He must call on his scientific knowledge and unorthodox ideas to save everything on Earth from extinction.',
#   'popularity': 152.9971,
#   'poster_path': '/yihdXomYb5kTeSivtFndMy5iDmf.jpg',
#   'release_date': '2026-03-15',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.658,
#   'vote_count': 6912},
#  {'adult': False,
#   'backdrop_path': '/3HaqAPZ0C8n6Hd5T86U53yJlBAN.jpg',
#   'genre_ids': [18, 10749],
#   'id': 1232449,
#   'title': 'Young Hearts',
#   'original_language': 'nl',
#   'original_title': 'Young Hearts',
#   'overview': '14-year-old Elias increasingly feels like an outsider in his village. When he meets his new neighbour of the same age, Alexander, Elias is confronted with his burgeoning sexuality.',
#   'popularity': 12.8086,
#   'poster_path': '/iGCtYxfuvXfy0BD5m6p7vKuPOxS.jpg',
#   'release_date': '2024-10-26',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.584,
#   'vote_count': 302},
#  {'adult': False,
#   'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#   'genre_ids': [18, 80],
#   'id': 240,
#   'title': 'The Godfather Part II',
#   'original_language': 'en',
#   'original_title': 'The Godfather Part II',
#   'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#   'popularity': 33.9582,
#   'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#   'release_date': '1974-12-20',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.571,
#   'vote_count': 14151},
#  {'adult': False,
#   'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#   'genre_ids': [18, 36, 10752],
#   'id': 424,
#   'title': "Schindler's List",
#   'original_language': 'en',
#   'original_title': "Schindler's List",
#   'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#   'popularity': 27.339,
#   'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#   'release_date': '1993-12-15',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.57,
#   'vote_count': 17712},
#  {'adult': False,
#   'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg',
#   'genre_ids': [18],
#   'id': 389,
#   'title': '12 Angry Men',
#   'original_language': 'en',
#   'original_title': '12 Angry Men',
#   'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#   'popularity': 24.5472,
#   'poster_path': '/ppd84D2i9W8jXmsyInGyihiSyqz.jpg',
#   'release_date': '1957-04-10',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.567,
#   'vote_count': 10211},
#  {'adult': False,
#   'backdrop_path': '/dyJvKsNs2KP8qQnAXbRwDjblViy.jpg',
#   'genre_ids': [16, 10751, 14],
#   'id': 129,
#   'title': 'Spirited Away',
#   'original_language': 'ja',
#   'original_title': '千と千尋の神隠し',
#   'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#   'popularity': 35.7703,
#   'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#   'release_date': '2001-07-20',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.534,
#   'vote_count': 18661},
#  {'adult': False,
#   'backdrop_path': '/dqK9Hag1054tghRQSqLSfrkvQnA.jpg',
#   'genre_ids': [28, 80, 53],
#   'id': 155,
#   'title': 'The Dark Knight',
#   'original_language': 'en',
#   'original_title': 'The Dark Knight',
#   'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#   'popularity': 63.6154,
#   'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#   'release_date': '2008-07-16',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.534,
#   'vote_count': 36332},
#  {'adult': False,
#   'backdrop_path': '/fr7F7156W8A5lSvrqHwNjtyrmLG.jpg',
#   'genre_ids': [16, 28, 10749, 14],
#   'id': 1218925,
#   'title': 'Chainsaw Man - The Movie: Reze Arc',
#   'original_language': 'ja',
#   'original_title': '劇場版 チェンソーマン レゼ篇',
#   'overview': "In a brutal war between devils, hunters, and secret enemies, a mysterious girl named Reze has stepped into Denji's world, and he faces his deadliest battle yet, fueled by love in a world where survival knows no rules.",
#   'popularity': 30.7289,
#   'poster_path': '/crBfxNvvsQV3rATX12EuX4W9ECo.jpg',
#   'release_date': '2025-09-19',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 1093},
#  {'adult': False,
#   'backdrop_path': '/84beTJf26mfhoasUlKSOiNSutyS.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 14.183,
#   'poster_path': '/lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg',
#   'release_date': '1995-10-20',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.506,
#   'vote_count': 4609},
#  {'adult': False,
#   'backdrop_path': '/amZavErrjrdgDwhsIdpWxHNenIx.jpg',
#   'genre_ids': [14, 18, 80],
#   'id': 497,
#   'title': 'The Green Mile',
#   'original_language': 'en',
#   'original_title': 'The Green Mile',
#   'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#   'popularity': 35.8835,
#   'poster_path': '/8VG8fDNiy50H4FedGwdSVUPoaJe.jpg',
#   'release_date': '1999-12-10',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.506,
#   'vote_count': 19576},
#  {'adult': False,
#   'backdrop_path': '/2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg',
#   'genre_ids': [12, 14, 28],
#   'id': 122,
#   'title': 'The Lord of the Rings: The Return of the King',
#   'original_language': 'en',
#   'original_title': 'The Lord of the Rings: The Return of the King',
#   'overview': 'As armies mass for a final battle that will decide the fate of the world--and powerful, ancient forces of Light and Dark compete to determine the outcome--one member of the Fellowship of the Ring is revealed as the noble heir to the throne of the Kings of Men. Yet, the sole hope for triumph over evil lies with a brave hobbit, Frodo, who, accompanied by his loyal friend Sam and the hideous, wretched Gollum, ventures deep into the very dark heart of Mordor on his seemingly impossible quest to destroy the Ring of Power.\u200b',
#   'popularity': 54.9428,
#   'poster_path': '/rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg',
#   'release_date': '2003-12-17',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.503,
#   'vote_count': 27044},
#  {'adult': False,
#   'backdrop_path': '/vbC0rzdrb7Ohc2TkbEbxtOABECe.jpg',
#   'genre_ids': [35, 53, 18],
#   'id': 496243,
#   'title': 'Parasite',
#   'original_language': 'ko',
#   'original_title': '기생충',
#   'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#   'popularity': 39.6266,
#   'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#   'release_date': '2019-05-30',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 21044},
#  {'adult': False,
#   'backdrop_path': '/5XNQBqnBwPA9yT0jZ0p3s8bbLh0.jpg',
#   'genre_ids': [12, 18, 878],
#   'id': 157336,
#   'title': 'Interstellar',
#   'original_language': 'en',
#   'original_title': 'Interstellar',
#   'overview': 'The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.',
#   'popularity': 70.0224,
#   'poster_path': '/yQvGrMoipbRoddT0ZR8tPoR7NfX.jpg',
#   'release_date': '2014-11-05',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.484,
#   'vote_count': 40677}]

# %% [markdown]
# **Converting in dataframe**

# %%
pd.DataFrame(response.json()["results"])
# Out:
#     adult                     backdrop_path            genre_ids       id  \
# 0   False  /ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg     [16, 28, 12, 14]   980431
# 1   False  /iCML6fBe3X0y06P33bM7dyYXPKZ.jpg          [35, 10749]  1632181
# 2   False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 3   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
# 4   False  /ufSwlnECLoUbBjPrFqEQcWBzHwc.jpg          [10402, 18]   936075
# 5   False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg             [18, 80]      238
# 6   False  /1RgPyOhN4DRs225BGTlHJqCudII.jpg         [16, 28, 14]  1311031
# 7   False  /8Tfys3mDZVp4tNoH2ktm06a0Tau.jpg            [878, 12]   687163
# 8   False  /3HaqAPZ0C8n6Hd5T86U53yJlBAN.jpg          [18, 10749]  1232449
# 9   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg             [18, 80]      240
# 10  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg      [18, 36, 10752]      424
# 11  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                 [18]      389
# 12  False  /dyJvKsNs2KP8qQnAXbRwDjblViy.jpg      [16, 10751, 14]      129
# 13  False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg         [28, 80, 53]      155
# 14  False  /fr7F7156W8A5lSvrqHwNjtyrmLG.jpg  [16, 28, 10749, 14]  1218925
# 15  False  /84beTJf26mfhoasUlKSOiNSutyS.jpg      [35, 18, 10749]    19404
# 16  False  /amZavErrjrdgDwhsIdpWxHNenIx.jpg         [14, 18, 80]      497
# 17  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg         [12, 14, 28]      122
# 18  False  /vbC0rzdrb7Ohc2TkbEbxtOABECe.jpg         [35, 53, 18]   496243
# 19  False  /5XNQBqnBwPA9yT0jZ0p3s8bbLh0.jpg        [12, 18, 878]   157336
#
#                                              title original_language  \
# 0                  Avatar Aang: The Last Airbender                en
# 1                              Accidental Partners                es
# 2                                          Swapped                en
# 3                         The Shawshank Redemption                en
# 4                                          Michael                en
# 5                                    The Godfather                en
# 6   Demon Slayer: Kimetsu no Yaiba Infinity Castle                ja
# 7                                Project Hail Mary                en
# 8                                     Young Hearts                nl
# 9                            The Godfather Part II                en
# 10                                Schindler's List                en
# 11                                    12 Angry Men                en
# 12                                   Spirited Away                ja
# 13                                 The Dark Knight                en
# 14              Chainsaw Man - The Movie: Reze Arc                ja
# 15                     Dilwale Dulhania Le Jayenge                hi
# 16                                  The Green Mile                en
# 17   The Lord of the Rings: The Return of the King                en
# 18                                        Parasite                ko
# 19                                    Interstellar                en
#
#                                    original_title  \
# 0                 Avatar Aang: The Last Airbender
# 1                            Socias por accidente
# 2                                         Swapped
# 3                        The Shawshank Redemption
# 4                                         Michael
# 5                                   The Godfather
# 6                         劇場版「鬼滅の刃」無限城編 第一章 猗窩座再来
# 7                               Project Hail Mary
# 8                                    Young Hearts
# 9                           The Godfather Part II
# 10                               Schindler's List
# 11                                   12 Angry Men
# 12                                       千と千尋の神隠し
# 13                                The Dark Knight
# 14                                劇場版 チェンソーマン レゼ篇
# 15                   दिलवाले दुल्हनिया ले जायेंगे
# 16                                 The Green Mile
# 17  The Lord of the Rings: The Return of the King
# 18                                            기생충
# 19                                   Interstellar
#
#                                              overview  popularity  \
# 0   Avatar Aang, the world's last Airbender, learn...    174.4534
# 1   Two women discover they were both scammed by t...     25.2919
# 2   A small woodland creature and a majestic bird,...     65.6704
# 3   Imprisoned in the 1940s for the double murder ...     64.6793
# 4   The story of Michael Jackson, one of the most ...     89.4142
# 5   Spanning the years 1945 to 1955, a chronicle o...     48.1392
# 6   The Demon Slayer Corps are drawn into the Infi...    120.8045
# 7   Science teacher Ryland Grace wakes up on a spa...    152.9971
# 8   14-year-old Elias increasingly feels like an o...     12.8086
# 9   In the continuing saga of the Corleone crime f...     33.9582
# 10  The true story of how businessman Oskar Schind...     27.3390
# 11  The defense and the prosecution have rested an...     24.5472
# 12  A young girl, Chihiro, becomes trapped in a st...     35.7703
# 13  Batman raises the stakes in his war on crime. ...     63.6154
# 14  In a brutal war between devils, hunters, and s...     30.7289
# 15  Raj is a rich, carefree, happy-go-lucky second...     14.1830
# 16  A supernatural tale set on death row in a Sout...     35.8835
# 17  As armies mass for a final battle that will de...     54.9428
# 18  All unemployed, Ki-taek's family takes peculia...     39.6266
# 19  The adventures of a group of explorers who mak...     70.0224
#
#                          poster_path release_date  softcore  video  \
# 0   /3sgnSfNT27Bx5O5ukr7B26mhEQq.jpg   2026-07-24     False  False
# 1   /j0CIVzeR7hRAPBPGR54qDZoOQpp.jpg   2026-03-12     False  False
# 2   /tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg   2026-05-01     False  False
# 3   /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23     False  False
# 4   /zm0KAbOjlt9eR5y7vDiL2dEOwMl.jpg   2026-04-22     False  False
# 5   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14     False  False
# 6   /fWVSwgjpT2D78VUh6X8UBd2rorW.jpg   2025-07-18     False  False
# 7   /yihdXomYb5kTeSivtFndMy5iDmf.jpg   2026-03-15     False  False
# 8   /iGCtYxfuvXfy0BD5m6p7vKuPOxS.jpg   2024-10-26     False  False
# 9   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     False  False
# 10  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15     False  False
# 11  /ppd84D2i9W8jXmsyInGyihiSyqz.jpg   1957-04-10     False  False
# 12  /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20     False  False
# 13  /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16     False  False
# 14  /crBfxNvvsQV3rATX12EuX4W9ECo.jpg   2025-09-19     False  False
# 15  /lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg   1995-10-20     False  False
# 16  /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10     False  False
# 17  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-17     False  False
# 18  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30     False  False
# 19  /yQvGrMoipbRoddT0ZR8tPoR7NfX.jpg   2014-11-05     False  False
#
#     vote_average  vote_count
# 0          9.266         779
# 1          8.899         347
# 2          8.886        2083
# 3          8.727       30979
# 4          8.691        3952
# 5          8.686       23307
# 6          8.679        1753
# 7          8.658        6912
# 8          8.584         302
# 9          8.571       14151
# 10         8.570       17712
# 11         8.567       10211
# 12         8.534       18661
# 13         8.534       36332
# 14         8.500        1093
# 15         8.506        4609
# 16         8.506       19576
# 17         8.503       27044
# 18         8.500       21044
# 19         8.484       40677
